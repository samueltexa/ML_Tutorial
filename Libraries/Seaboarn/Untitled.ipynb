# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
x = [10,20,30,40]

# %%
y = [0,15,10,25]

# %%
plt.plot(x,y)

# %%
sns.set()

# %%
plt.plot(x,y)

# %%
sns.set_style("white")

# %%
plt.plot(x,y)
